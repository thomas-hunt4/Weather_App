# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Lebrija_Espana.csv', skiprows=2)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394488 entries, 0 to 394487
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      394488 non-null  object
#  1   temperature_2m (°C)       394488 non-null  float64
#  2   precipitation (mm)        394488 non-null  float64
#  3   relative_humidity_2m (%)  394488 non-null  int64
#  4   pressure_msl (hPa)        394488 non-null  float64
#  5   surface_pressure (hPa)    394488 non-null  float64
#  6   cloud_cover_low (%)       394488 non-null  int64
#  7   cloud_cover_mid (%)       394488 non-null  int64
#  8   cloud_cover_high (%)      394488 non-null  int64
#  9   wind_speed_10m (km/h)     394488 non-null  float64
#  10  wind_speed_100m (km/h)    394488 non-null  float64
#  11  wind_direction_10m (°)    394488 non-null  int64
#  12  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 39.1+ MB
# None

# %%
print(df.describe())
# Out:
#        temperature_2m (°C)  precipitation (mm)  relative_humidity_2m (%)  \
# count        394488.000000       394488.000000             394488.000000
# mean             18.266834            0.057955                 66.438599
# std               7.370001            0.348653                 21.548327
# min              -2.500000            0.000000                  4.000000
# 25%              12.900000            0.000000                 50.000000
# 50%              17.700000            0.000000                 69.000000
# 75%              23.000000            0.000000                 85.000000
# max              44.300000           15.400000                100.000000
#
#        pressure_msl (hPa)  surface_pressure (hPa)  cloud_cover_low (%)  \
# count       394488.000000           394488.000000        394488.000000
# mean          1017.242622             1012.719942            13.024333
# std              5.848411                5.783024            27.198874
# min            981.800000              977.300000             0.000000
# 25%           1013.600000             1009.200000             0.000000
# 50%           1016.500000             1012.000000             0.000000
# 75%           1020.600000             1016.100000             9.000000
# max           1040.800000             1036.100000           100.000000
#
#        cloud_cover_mid (%)  cloud_cover_high (%)  wind_speed_10m (km/h)  \
# count        394488.000000         394488.000000          394488.000000
# mean             12.372931             25.200166               9.547219
# std              25.012634             37.439112               5.197780
# min               0.000000              0.000000               0.000000
# 25%               0.000000              0.000000               6.100000
# 50%               0.000000              0.000000               8.300000
# 75%              11.000000             49.000000              12.100000
# max             100.000000            100.000000              59.800000
#
#        wind_speed_100m (km/h)  wind_direction_10m (°)  wind_direction_100m (°)
# count           394488.000000           394488.000000            394488.000000
# mean                15.758758              178.518026               184.041461
# std                  8.429497               99.815243               100.569791
# min                  0.000000                1.000000                 0.000000
# 25%                  9.400000               77.000000                82.000000
# 50%                 15.100000              200.000000               210.000000
# 75%                 20.800000              253.000000               259.000000
# max                 91.200000              360.000000               360.000000

# %%
newdf = df.dropna()

# %%
print(newdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394488 entries, 0 to 394487
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      394488 non-null  object
#  1   temperature_2m (°C)       394488 non-null  float64
#  2   precipitation (mm)        394488 non-null  float64
#  3   relative_humidity_2m (%)  394488 non-null  int64
#  4   pressure_msl (hPa)        394488 non-null  float64
#  5   surface_pressure (hPa)    394488 non-null  float64
#  6   cloud_cover_low (%)       394488 non-null  int64
#  7   cloud_cover_mid (%)       394488 non-null  int64
#  8   cloud_cover_high (%)      394488 non-null  int64
#  9   wind_speed_10m (km/h)     394488 non-null  float64
#  10  wind_speed_100m (km/h)    394488 non-null  float64
#  11  wind_direction_10m (°)    394488 non-null  int64
#  12  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 39.1+ MB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394488 entries, 0 to 394487
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      394488 non-null  object
#  1   temperature_2m (°C)       394488 non-null  float64
#  2   precipitation (mm)        394488 non-null  float64
#  3   relative_humidity_2m (%)  394488 non-null  int64
#  4   pressure_msl (hPa)        394488 non-null  float64
#  5   surface_pressure (hPa)    394488 non-null  float64
#  6   cloud_cover_low (%)       394488 non-null  int64
#  7   cloud_cover_mid (%)       394488 non-null  int64
#  8   cloud_cover_high (%)      394488 non-null  int64
#  9   wind_speed_10m (km/h)     394488 non-null  float64
#  10  wind_speed_100m (km/h)    394488 non-null  float64
#  11  wind_direction_10m (°)    394488 non-null  int64
#  12  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 39.1+ MB
# None

# %%
df['date'] = pd.to_datetime(df['time'])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394488 entries, 0 to 394487
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      394488 non-null  object
#  1   temperature_2m (°C)       394488 non-null  float64
#  2   precipitation (mm)        394488 non-null  float64
#  3   relative_humidity_2m (%)  394488 non-null  int64
#  4   pressure_msl (hPa)        394488 non-null  float64
#  5   surface_pressure (hPa)    394488 non-null  float64
#  6   cloud_cover_low (%)       394488 non-null  int64
#  7   cloud_cover_mid (%)       394488 non-null  int64
#  8   cloud_cover_high (%)      394488 non-null  int64
#  9   wind_speed_10m (km/h)     394488 non-null  float64
#  10  wind_speed_100m (km/h)    394488 non-null  float64
#  11  wind_direction_10m (°)    394488 non-null  int64
#  12  wind_direction_100m (°)   394488 non-null  int64
#  13  date                      394488 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(6), object(1)
# memory usage: 42.1+ MB
# None

# %%
df.set_index('date', inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 394488 entries, 1980-07-01 00:00:00 to 2025-07-01 23:00:00
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      394488 non-null  object
#  1   temperature_2m (°C)       394488 non-null  float64
#  2   precipitation (mm)        394488 non-null  float64
#  3   relative_humidity_2m (%)  394488 non-null  int64
#  4   pressure_msl (hPa)        394488 non-null  float64
#  5   surface_pressure (hPa)    394488 non-null  float64
#  6   cloud_cover_low (%)       394488 non-null  int64
#  7   cloud_cover_mid (%)       394488 non-null  int64
#  8   cloud_cover_high (%)      394488 non-null  int64
#  9   wind_speed_10m (km/h)     394488 non-null  float64
#  10  wind_speed_100m (km/h)    394488 non-null  float64
#  11  wind_direction_10m (°)    394488 non-null  int64
#  12  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 42.1+ MB
# None

# %%
df.drop(columns='time', inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 394488 entries, 1980-07-01 00:00:00 to 2025-07-01 23:00:00
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   temperature_2m (°C)       394488 non-null  float64
#  1   precipitation (mm)        394488 non-null  float64
#  2   relative_humidity_2m (%)  394488 non-null  int64
#  3   pressure_msl (hPa)        394488 non-null  float64
#  4   surface_pressure (hPa)    394488 non-null  float64
#  5   cloud_cover_low (%)       394488 non-null  int64
#  6   cloud_cover_mid (%)       394488 non-null  int64
#  7   cloud_cover_high (%)      394488 non-null  int64
#  8   wind_speed_10m (km/h)     394488 non-null  float64
#  9   wind_speed_100m (km/h)    394488 non-null  float64
#  10  wind_direction_10m (°)    394488 non-null  int64
#  11  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6)
# memory usage: 39.1 MB
# None

# %%
df.corr()
# Out:
#                           temperature_2m (°C)  precipitation (mm)  \
# temperature_2m (°C)                  1.000000           -0.067298
# precipitation (mm)                  -0.067298            1.000000
# relative_humidity_2m (%)            -0.735291            0.155906
# pressure_msl (hPa)                  -0.350360           -0.218115
# surface_pressure (hPa)              -0.333167           -0.220892
# cloud_cover_low (%)                 -0.192368            0.308658
# cloud_cover_mid (%)                 -0.150349            0.365883
# cloud_cover_high (%)                -0.110335            0.183393
# wind_speed_10m (km/h)                0.047345            0.240793
# wind_speed_100m (km/h)              -0.131022            0.243599
# wind_direction_10m (°)               0.240657            0.019092
# wind_direction_100m (°)              0.199129            0.014997
#
#                           relative_humidity_2m (%)  pressure_msl (hPa)  \
# temperature_2m (°C)                      -0.735291           -0.350360
# precipitation (mm)                        0.155906           -0.218115
# relative_humidity_2m (%)                  1.000000            0.128096
# pressure_msl (hPa)                        0.128096            1.000000
# surface_pressure (hPa)                    0.114632            0.999820
# cloud_cover_low (%)                       0.315963           -0.133281
# cloud_cover_mid (%)                       0.182652           -0.270011
# cloud_cover_high (%)                      0.153646           -0.099795
# wind_speed_10m (km/h)                    -0.145024           -0.283610
# wind_speed_100m (km/h)                    0.033424           -0.240539
# wind_direction_10m (°)                   -0.107087           -0.279848
# wind_direction_100m (°)                  -0.044858           -0.274878
#
#                           surface_pressure (hPa)  cloud_cover_low (%)  \
# temperature_2m (°C)                    -0.333167            -0.192368
# precipitation (mm)                     -0.220892             0.308658
# relative_humidity_2m (%)                0.114632             0.315963
# pressure_msl (hPa)                      0.999820            -0.133281
# surface_pressure (hPa)                  1.000000            -0.137894
# cloud_cover_low (%)                    -0.137894             1.000000
# cloud_cover_mid (%)                    -0.274689             0.409204
# cloud_cover_high (%)                   -0.102536             0.167079
# wind_speed_10m (km/h)                  -0.284580             0.237952
# wind_speed_100m (km/h)                 -0.244701             0.216547
# wind_direction_10m (°)                 -0.276952             0.087280
# wind_direction_100m (°)                -0.272766             0.092803
#
#                           cloud_cover_mid (%)  cloud_cover_high (%)  \
# temperature_2m (°C)                 -0.150349             -0.110335
# precipitation (mm)                   0.365883              0.183393
# relative_humidity_2m (%)             0.182652              0.153646
# pressure_msl (hPa)                  -0.270011             -0.099795
# surface_pressure (hPa)              -0.274689             -0.102536
# cloud_cover_low (%)                  0.409204              0.167079
# cloud_cover_mid (%)                  1.000000              0.344702
# cloud_cover_high (%)                 0.344702              1.000000
# wind_speed_10m (km/h)                0.267755              0.080017
# wind_speed_100m (km/h)               0.273191              0.096398
# wind_direction_10m (°)               0.042729             -0.033800
# wind_direction_100m (°)              0.039612             -0.032099
#
#                           wind_speed_10m (km/h)  wind_speed_100m (km/h)  \
# temperature_2m (°C)                    0.047345               -0.131022
# precipitation (mm)                     0.240793                0.243599
# relative_humidity_2m (%)              -0.145024                0.033424
# pressure_msl (hPa)                    -0.283610               -0.240539
# surface_pressure (hPa)                -0.284580               -0.244701
# cloud_cover_low (%)                    0.237952                0.216547
# cloud_cover_mid (%)                    0.267755                0.273191
# cloud_cover_high (%)                   0.080017                0.096398
# wind_speed_10m (km/h)                  1.000000                0.903306
# wind_speed_100m (km/h)                 0.903306                1.000000
# wind_direction_10m (°)                 0.107721                0.068432
# wind_direction_100m (°)                0.075189                0.045608
#
#                           wind_direction_10m (°)  wind_direction_100m (°)
# temperature_2m (°C)                     0.240657                 0.199129
# precipitation (mm)                      0.019092                 0.014997
# relative_humidity_2m (%)               -0.107087                -0.044858
# pressure_msl (hPa)                     -0.279848                -0.274878
# surface_pressure (hPa)                 -0.276952                -0.272766
# cloud_cover_low (%)                     0.087280                 0.092803
# cloud_cover_mid (%)                     0.042729                 0.039612
# cloud_cover_high (%)                   -0.033800                -0.032099
# wind_speed_10m (km/h)                   0.107721                 0.075189
# wind_speed_100m (km/h)                  0.068432                 0.045608
# wind_direction_10m (°)                  1.000000                 0.891127
# wind_direction_100m (°)                 0.891127                 1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 394488 entries, 1980-07-01 00:00:00 to 2025-07-01 23:00:00
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   temperature_2m (°C)       394488 non-null  float64
#  1   precipitation (mm)        394488 non-null  float64
#  2   relative_humidity_2m (%)  394488 non-null  int64
#  3   pressure_msl (hPa)        394488 non-null  float64
#  4   surface_pressure (hPa)    394488 non-null  float64
#  5   cloud_cover_low (%)       394488 non-null  int64
#  6   cloud_cover_mid (%)       394488 non-null  int64
#  7   cloud_cover_high (%)      394488 non-null  int64
#  8   wind_speed_10m (km/h)     394488 non-null  float64
#  9   wind_speed_100m (km/h)    394488 non-null  float64
#  10  wind_direction_10m (°)    394488 non-null  int64
#  11  wind_direction_100m (°)   394488 non-null  int64
# dtypes: float64(6), int64(6)
# memory usage: 39.1 MB

# %%
print(df.columns)
# Out:
# Index(['temperature_2m (°C)', 'precipitation (mm)', 'relative_humidity_2m (%)',
#        'pressure_msl (hPa)', 'surface_pressure (hPa)', 'cloud_cover_low (%)',
#        'cloud_cover_mid (%)', 'cloud_cover_high (%)', 'wind_speed_10m (km/h)',
#        'wind_speed_100m (km/h)', 'wind_direction_10m (°)',
#        'wind_direction_100m (°)'],
#       dtype='object')

# %%
df['temperature_2m (°C)'].plot()
plt.show()
